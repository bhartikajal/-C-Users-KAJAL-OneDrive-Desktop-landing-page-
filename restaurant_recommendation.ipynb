# %% [markdown]
# <a href="https://colab.research.google.com/github/bhartikajal/-C-Users-KAJAL-OneDrive-Desktop-landing-page-project/blob/master/restaurant_recommendation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df =pd.read_csv("/content/Dataset  (1).csv")

# %%
df.head(20)
# Out:
#     Restaurant ID                           Restaurant Name  Country Code  \
# 0         6317637                          Le Petit Souffle           162
# 1         6304287                          Izakaya Kikufuji           162
# 2         6300002                    Heat - Edsa Shangri-La           162
# 3         6318506                                      Ooma           162
# 4         6314302                               Sambo Kojin           162
# 5        18189371                              Din Tai Fung           162
# 6         6300781                                Buffet 101           162
# 7         6301290                                   Vikings           162
# 8         6300010  Spiral - Sofitel Philippine Plaza Manila           162
# 9         6314987                                  Locavore           162
# 10        6309903                          Silantro Fil-Mex           162
# 11        6309455           Mad Mark's Creamery & Good Eats           162
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
# group by city ans calculate average cost
df.groupby("City")["Average Cost for two"].mean().sort_values(ascending=False).head().plot(kind="bar")
plt.title("Average cost for two per city,top 5")
plt.xlabel("City")
plt.ylabel("Amount")

plt.show()

# %%
#cuisines total number of votess
data=df.groupby("Cuisines")["Votes"].sum().reset_index()

# %%
data[data["Votes"] ==0]
# Out:
#                                                Cuisines  Votes
# 2                                 Afghani, North Indian      0
# 164                                     Awadhi, Mughlai      0
# 185                       Bakery, Chinese, North Indian      0
# 193                 Bakery, Desserts, Fast Food, Mithai      0
# 208                                Bakery, Healthy Food      0
# 213                                Bakery, North Indian      0
# 214                                       Bakery, Pizza      0
# 224                                    Bengali, Chinese      0
# 234                             Beverages, Healthy Food      0
# 323                            Burger, Pizza, Fast Food      0
# 457                          Cafe, Mexican, Continental      0
# 463                                 Cafe, North Eastern      0
# 489                                       Cafe, Tibetan      0
# 524                           Chinese, Fast Food, Pizza      0
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
sns.pairplot(df[["Average Cost for two","Aggregate rating","Votes"]])

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df["Has Online delivery"].value_counts().plot(kind="pie")
plt.title("Has OnlineDelivery?")
plt.ylabel("")
plt.legend()
plt.show()

# %%
df[["Aggregate rating","Rating text"]].head().sort_values(by="Aggregate rating",ascending=True).head(7000)
# Out:
#    Aggregate rating Rating text
# 2               4.4   Very Good
# 1               4.5   Excellent
# 0               4.8   Excellent
# 4               4.8   Excellent
# 3               4.9   Excellent

# %%
df=df[df["Rating text"]!="Not rated"]

# %%
df["Rating text"].value_counts().plot(kind="pie")
plt.title("Rating Averages")
plt.ylabel("")
plt.show()

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
X=df[['Average Cost for two',"Has Table booking","Has Online delivery","Price range"]]

# %%
#Above 2 below 2.5  poor
#Above 2.5 below 3.5 Average
#Above 3.5 below 4.0 Good
#Above 4 below 4.5 Very Good
#Above 4.5 Excellent

# %%
Y=df[["Aggregate rating"]]

# %%
X
# Out:
#       Average Cost for two Has Table booking Has Online delivery  Price range
# 0                     1100               Yes                  No            3
# 1                     1200               Yes                  No            3
# 2                     4000               Yes                  No            4
# 3                     1500                No                  No            4
# 4                     1500               Yes                  No            4
# ...                    ...               ...                 ...          ...
# 9546                    80                No                  No            3
# 9547                   105                No                  No            3
# 9548                   170                No                  No            4
# 9549                   120                No                  No            4
# 9550                    55                No                  No            2
#
# [7403 rows x 4 columns]

# %%
from sklearn import preprocessing
LabelEncoder =preprocessing.LabelEncoder()

# %%
X["Has Table booking"] = LabelEncoder.fit_transform(X["Has Table booking"])
# Out:
# <ipython-input-43-0dc0b67260be>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Has Table booking"] = LabelEncoder.fit_transform(X["Has Table booking"])

# %%
X
# Out:
#       Average Cost for two  Has Table booking Has Online delivery  Price range
# 0                     1100                  1                  No            3
# 1                     1200                  1                  No            3
# 2                     4000                  1                  No            4
# 3                     1500                  0                  No            4
# 4                     1500                  1                  No            4
# ...                    ...                ...                 ...          ...
# 9546                    80                  0                  No            3
# 9547                   105                  0                  No            3
# 9548                   170                  0                  No            4
# 9549                   120                  0                  No            4
# 9550                    55                  0                  No            2
#
# [7403 rows x 4 columns]

# %%
X["Has Online delivery"] = LabelEncoder.fit_transform(X["Has Online delivery"])
# Out:
# <ipython-input-45-76349b159fa3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X["Has Online delivery"] = LabelEncoder.fit_transform(X["Has Online delivery"])

# %%
LabelEncoder.classes_
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler
Scaler =StandardScaler()

# %%
X =Scaler.fit_transform(X)

# %%
X
# Out:
# array([[-0.0190367 ,  2.37978283, -0.68302371,  1.10671644],
#        [-0.0135729 ,  2.37978283, -0.68302371,  1.10671644],
#        [ 0.13941344,  2.37978283, -0.68302371,  2.18135204],
#        ...,
#        [-0.06985002, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07258191, -0.42020641, -0.68302371,  2.18135204],
#        [-0.07613338, -0.42020641, -0.68302371,  0.03208084]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test =train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
import numpy as np

# %%
def modelresults(prediction):
  print("Mean absolute error on model is {}".formate(mean-mean_absolute_error(Y_test,prediction)))
  print("Root mean square error on model is {}".formate(np.sqrt(mean_squared_error(Y_test,prediction))))

# %%
from sklearn.linear_model import LinearRegression
lr =LinearRegression()

# %%
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
predictionsfromlr= lr.predict(X_test)

# %%
predictionsfromlr
# Out:
# array([[3.42261053],
#        [3.61535204],
#        [3.42261053],
#        ...,
#        [3.61535204],
#        [3.49035857],
#        [3.75357141]])

# %%
from sklearn.svm import SVR
from sklearn.model_selection import GridSearchCV

# %%
svrmodel =SVR()

# %%
param_gridsvr ={"C": [0.001,0.01,0.1,0.5],"Kernel" :["linear","rbf","ploy"],"degree" :[1,2,3,4]}

# %%
gridsvr =GridSearchCV(svrmodel,param_gridsvr)
gridsvr.fit(X_train,Y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-91-1a5fae801989> in <cell line: 2>()
#       1 gridsvr =GridSearchCV(svrmodel,param_gridsvr)
# ----> 2 gridsvr.fit(X_train,Y_train)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     872                 return results
#     873
# --> 874             self._run_search(evaluate_candidates)
#     875
#     876             # multimetric is determined here because in the case of a callable
#
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1386     def _run_search(self, evaluate_candidates):
#    1387         """Search all candidates in param_grid"""
# -> 1388         evaluate_candidates(ParameterGrid(self.param_grid))
#    1389
#    1390
#
# ...

# %%
# Preprocess the new data data
new_data_preprocessed = preprocessor.transform(new_data)

# %%
# Load the saved model
loaded_model = joblib.load('restaurant_rating_model.joblib')

# %%
# Make prediction on the new data
new_rating_pred = loaded_model.predict(new_data_preprocessed)

# %%
# Display the prediction
print(f'Predicted Aggregate Rating for new Data: {new_rating_pred[0]}')
